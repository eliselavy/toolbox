# %% [markdown]
# # Test made at home

# %% [markdown]
# ## 50 threads ramp up 5

# %% [markdown]
# <img src="results/50 users rampup 5.png"></img>

# %% [markdown]
# - Sample - number of requests sent
# - Average - an Arithmetic mean for all responses (sum of all times / count)
# - Minimal response time (ms)
# - Maximum response time (ms)
# - Deviation - see Standard Deviation article
# - Error rate - percentage of failed tests
# - Throughput - how many requests per second does your server handle. Larger is better.
# - KB/Sec - self expalanatory
# - Avg. Bytes - average response size

# %% [markdown]
# ## 100 threads ramp up 5

# %% [markdown]
# <img src="results/100 users rampup 5.png"></img>

# %% [markdown]
# ## 200 threads ramp up 5

# %% [markdown]
# <img src="results/200 users rampup 5.png"></img>

# %% [markdown]
# ### By updating the JVM_ARGS

# %%
JVM_ARGS="-Xms1g -Xmx4g" jmeter -n -t JDH_blaze.jmx -l results_200_HEAP_threads.csv

# %%
import pandas as pd
result_df = pd.read_csv("results_200_HEAP_threads.csv", sep=",")
result_df
# Out:
#           timeStamp  elapsed          label  responseCode    responseMessage  \
# 0     1631175225331       38    Issues list           200                 OK
# 1     1631175225331       22  Issues list-0           301  Moved Permanently
# 2     1631175225355       14  Issues list-1           200                 OK
# 3     1631175225312       68    Issues list           200                 OK
# 4     1631175225312       41  Issues list-0           301  Moved Permanently
# ...             ...      ...            ...           ...                ...
# 2195  1631175236463    50040     Raw github           200                 OK
# 2196  1631175236651    49927     Raw github           200                 OK
# 2197  1631175240209    46424     Raw github           200                 OK
# 2198  1631175236229    50538     Raw github           200                 OK
# 2199  1631175231845    54938     Raw github           200                 OK
#
# ...

# %%
raw_github = result_df.loc[result_df['label'] == 'Raw github']
raw_github.loc[result_df['elapsed'] >= 10000]
# Out:
#           timeStamp  elapsed       label  responseCode responseMessage  \
# 1998  1631175228309    10086  Raw github           200              OK
# 2025  1631175228650    11864  Raw github           200              OK
# 2035  1631175228282    16712  Raw github           200              OK
# 2038  1631175231346    14131  Raw github           200              OK
# 2040  1631175234664    11271  Raw github           200              OK
# ...             ...      ...         ...           ...             ...
# 2195  1631175236463    50040  Raw github           200              OK
# 2196  1631175236651    49927  Raw github           200              OK
# 2197  1631175240209    46424  Raw github           200              OK
# 2198  1631175236229    50538  Raw github           200              OK
# 2199  1631175231845    54938  Raw github           200              OK
#
#               threadName dataType  success  failureMessage     bytes  \
# ...

# %% [markdown]
# >Elapsed time: Measures the elapsed time from just before sending the request to just after the last chunk of the response has been received,
#
# Elapsed Time / Connect Time / Latency: should be as low as possible, ideally less than 1 second. Amazon found every 100ms costs them 1% in sales, which translates to several millions of dollars lost

# %% [markdown]
# https://www.perfmatrix.com/jmeter-grafana-dashboard-using-influxdb/
#
# dashboard json https://grafana.com/grafana/dashboards/5496

# %% [markdown]
# # At the university

# %% [markdown]
# ## 50 threads ramp up 5 s

# %% [markdown]
# <img src="results/50 users rampup 5 UNI.png"></img>

# %% [markdown]
# ## 100 threads ramp up 5 s

# %% [markdown]
# <img src="results/100 users rampup 5 UNI.png"></img>

# %% [markdown]
# ## 200 threads ramp up 5s

# %% [markdown]
# <img src="results/200 users rampup 5 UNI.png"></img>

# %% [markdown]
# ## 200 threads ram up 5s and cache

# %% [markdown]
# <img src="results/200 users rampup 5 UNI Cache.png"></img>
